# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Fake News Detection Dataset.csv")

# %%
df.head()
# Out:
#      ID  Word_Count  Number_of_Sentence  Unique_Words  Average_Word_Length  \
# 0  1606          10                   4            24             6.176750
# 1  3718          10                   8            25             5.826770
# 2  2634          10                   7            18             4.619040
# 3  5560          10                   6            18             4.961424
# 4  7494          10                   4            21             4.114324
#
#    Label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.shape
# Out:
# (4500, 6)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Word_Count             0
# Number_of_Sentence     0
# Unique_Words           0
# Average_Word_Length    0
# Label                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   4500 non-null   int64
#  1   Word_Count           4500 non-null   int64
#  2   Number_of_Sentence   4500 non-null   int64
#  3   Unique_Words         4500 non-null   int64
#  4   Average_Word_Length  4500 non-null   float64
#  5   Label                4500 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 211.1 KB

# %%
df.drop("ID", axis=1, inplace=True)

# %%
df
# Out:
#       Word_Count  Number_of_Sentence  Unique_Words  Average_Word_Length  Label
# 0             10                   4            24             6.176750      1
# 1             10                   8            25             5.826770      1
# 2             10                   7            18             4.619040      1
# 3             10                   6            18             4.961424      1
# 4             10                   4            21             4.114324      1
# ...          ...                 ...           ...                  ...    ...
# 4495          41                   7            12             6.963924      0
# 4496         100                   5            15             3.136755      1
# 4497         100                   8            18             3.376823      1
# 4498          85                  14            42             5.331393      0
# 4499          57                   6             7             4.312751      0
#
# [4500 rows x 5 columns]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df['Word_Count'].unique()
# Out:
# array([ 10,  39,  11,  69,  12,  85,  13,  14,  94,  27,  28,  15,  42,
#         38,  20,  32,  36,  62,  24,  16,  55,  89,  60,  66,  17,  57,
#         18,  58,  19,  59,  48,  51,  44,  21,  34,  56,  68,  45,  78,
#         72,  52,  53,  86,  71,  43,  97,  22,  23,  25,  26,  40,  41,
#         46,  29,  47,  49,  50,  30,  54,  31,  33,  35,  64,  67,  37,
#         70,  77,  82,  87,  92,  98,  63,  80,  99,  83,  75,  93,  96,
#         74,  61,  73,  76,  90,  91,  88,  65, 100,  79,  95,  84,  81],
#       dtype=int64)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4495    False
# 4496    False
# 4497    False
# 4498    False
# 4499    False
# Length: 4500, dtype: bool

# %%
sns.boxplot(df['Number_of_Sentence'])
# Out:
# C:\Users\Administrator\Contacts\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Number_of_Sentence'>

# %% [markdown]
# # Histogram of Word_Count

# %%
# Histogram of Word_Count
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(df['Word_Count'], kde=True)
plt.title('Histogram of Word Count')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Box plot of Word_Count by Label

# %%
# Box plot of Word_Count by Label
plt.figure(figsize=(10, 6))
sns.boxplot(x='Label', y='Word_Count', data=df)
plt.title('Box Plot of Word Count by Label')
plt.xlabel('Label')
plt.ylabel('Word Count')
plt.show()

# %%
# Scatter plot of Word_Count vs Average_Word_Length
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Word_Count', y='Average_Word_Length', hue='Label', data=df)
plt.title('Scatter Plot of Word Count vs Average Word Length')
plt.xlabel('Word Count')
plt.ylabel('Average Word Length')
plt.show()

# %% [markdown]
# # COUNT OF FAKE VS REAL NEWS

# %%
# Custom color palette
plt.figure(figsize=(14, 7))
custom_palette = ["#3498db", "#e74c3c"]

df["Label"].value_counts().plot(kind='bar',color=custom_palette)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # COUNT OF FAKE VS REAL NEWS WITH PERCENTAGE

# %%
# Custom color palette
custom_palette = ["#3498db", "#e74c3c"]
plt.figure(figsize=(14, 7))
df["Label"].value_counts().plot(kind='pie',autopct="%0.2f%%",colors=custom_palette,)
# Out:
# <AxesSubplot:ylabel='Label'>

# %%
sns.pairplot(data=df,hue='Label')

# %%
df.corr()
# Out:
#                      Word_Count  Number_of_Sentence  Unique_Words  \
# Word_Count             1.000000            0.019283      0.000311
# Number_of_Sentence     0.019283            1.000000      0.064588
# Unique_Words           0.000311            0.064588      1.000000
# Average_Word_Length   -0.012532           -0.011598     -0.000833
# Label                 -0.048932           -0.214928     -0.299647
#
#                      Average_Word_Length     Label
# Word_Count                     -0.012532 -0.048932
# Number_of_Sentence             -0.011598 -0.214928
# Unique_Words                   -0.000833 -0.299647
# Average_Word_Length             1.000000  0.005308
# Label                           0.005308  1.000000

# %%
df.to_csv('Fake_news_detection.csv', index=False)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot =True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x = df.drop(columns=[ 'Label'], axis=1)
y = df['Label']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
x_scale = scaler.fit_transform(x)
x_scale
# Out:
# array([[0.        , 0.        , 0.42222222, 0.79420757],
#        [0.        , 0.36363636, 0.44444444, 0.70669981],
#        [0.        , 0.27272727, 0.28888889, 0.40472298],
#        ...,
#        [1.        , 0.36363636, 0.28888889, 0.0941235 ],
#        [0.83333333, 0.90909091, 0.82222222, 0.58283754],
#        [0.52222222, 0.18181818, 0.04444444, 0.3281397 ]])

# %%
x_scale = pd.DataFrame(x_scale, columns=x.columns)

print(x_scale.head())
# Out:
#    Word_Count  Number_of_Sentence  Unique_Words  Average_Word_Length
# 0         0.0            0.000000      0.422222             0.794208
# 1         0.0            0.363636      0.444444             0.706700
# 2         0.0            0.272727      0.288889             0.404723
# 3         0.0            0.181818      0.288889             0.490332
# 4         0.0            0.000000      0.355556             0.278526

# %%
from sklearn.model_selection import train_test_split
# Train test split 
X_train, X_test, y_train, y_test = train_test_split(x_scale, y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_absolute_percentage_error, mean_squared_error, roc_auc_score, auc, log_loss, precision_recall_fscore_support, mean_absolute_error
from sklearn.metrics import roc_curve

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_logistic = LogisticRegression()
model_logistic.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#y_pred = model_logistic.predict(scaled_X_test)
y_pred_train_LG = model_logistic.predict(X_train)
y_pred_test_lg = model_logistic.predict(X_test)
acc_train_3 = accuracy_score(y_train, y_pred_train_LG)
acc_test_3 = accuracy_score(y_test, y_pred_test_lg)

# Print classification report
print(classification_report(y_test, y_pred_test_lg))
print("Training Accuracy Score",acc_train_3)
print("Testing Accuracy Score",acc_test_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.85      0.75       595
#            1       0.41      0.21      0.28       305
#
#     accuracy                           0.63       900
#    macro avg       0.54      0.53      0.51       900
# weighted avg       0.59      0.63      0.59       900
#
# Training Accuracy Score 0.6355555555555555
# Testing Accuracy Score 0.6311111111111111

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred_train_RF = clf.predict(X_train)
y_pred_test_rf = clf.predict(X_test)
acc_train_3 = accuracy_score(y_train, y_pred_train_RF)
acc_test_3 = accuracy_score(y_test, y_pred_test_rf)
# Print classification report
print(classification_report(y_test, y_pred_test_rf))
print("Training Accuracy Score",acc_train_3)
print("Testing Accuracy Score",acc_test_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       595
#            1       0.78      0.95      0.85       305
#
#     accuracy                           0.89       900
#    macro avg       0.87      0.90      0.88       900
# weighted avg       0.90      0.89      0.89       900
#
# Training Accuracy Score 1.0
# Testing Accuracy Score 0.89

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

clf = RandomForestClassifier(n_estimators=1000, max_depth=10, min_samples_leaf=10)
clf.fit(X_train, y_train)

y_pred_train_RF = clf.predict(X_train)
y_pred_test_rf = clf.predict(X_test)

acc_train_3 = accuracy_score(y_train, y_pred_train_RF)
acc_test_3 = accuracy_score(y_test, y_pred_test_rf)

print(classification_report(y_test, y_pred_test_rf))
print("Training Accuracy Score", acc_train_3)
print("Testing Accuracy Score", acc_test_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       595
#            1       0.76      1.00      0.87       305
#
#     accuracy                           0.90       900
#    macro avg       0.88      0.92      0.89       900
# weighted avg       0.92      0.90      0.90       900
#
# Training Accuracy Score 0.9102777777777777
# Testing Accuracy Score 0.8955555555555555

# %%
import pickle

# Save the model to a file
with open('random_forest_model.pkl', 'wb') as f:
    pickle.dump(clf, f)
